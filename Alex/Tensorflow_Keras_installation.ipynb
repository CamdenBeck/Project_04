# %%
# !pip install tensorflow
# Out:
# ...
#    ---------------------------------------- 0.0/375.7 MB ? eta -:--:--
#    ---------------------------------------- 1.3/375.7 MB 9.6 MB/s eta 0:00:39
#    ---------------------------------------- 4.5/375.7 MB 12.8 MB/s eta 0:00:30
#     --------------------------------------- 7.6/375.7 MB 13.8 MB/s eta 0:00:27
#    - -------------------------------------- 12.1/375.7 MB 16.1 MB/s eta 0:00:23
#    - -------------------------------------- 16.8/375.7 MB 17.6 MB/s eta 0:00:21
#    -- ------------------------------------- 20.7/375.7 MB 17.4 MB/s eta 0:00:21
#    -- ------------------------------------- 26.0/375.7 MB 18.7 MB/s eta 0:00:19
#    --- ------------------------------------ 31.5/375.7 MB 19.6 MB/s eta 0:00:18
#    ---- ----------------------------------- 37.7/375.7 MB 20.5 MB/s eta 0:00:17
#    ---- ----------------------------------- 43.8/375.7 MB 21.4 MB/s eta 0:00:16
#    ----- ---------------------------------- 49.5/375.7 MB 22.1 MB/s eta 0:00:15
# ...

# %%
# !pip install keras-tuner

# %%
# !pip install scikeras
